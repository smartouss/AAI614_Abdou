# %% [markdown]
# <a href="https://colab.research.google.com/github/smartouss/AAI614_Abdou/blob/main/Week%203/Oussama%20Abdou_Outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
for feature in df.columns:
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[feature] < lower) | (df[feature] > upper)][feature]
    plt.figure(figsize=(9, 2.2))
    plt.boxplot(df[feature], vert=False, showmeans=True)
    if not outliers.empty:
      plt.scatter(outliers.values, np.ones(outliers.shape[0]))
    plt.title(f"IQR Outlier Detection — {feature}")
    plt.xlabel(feature)
    plt.show()
